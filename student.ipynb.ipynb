# %%
# !ls
# Out:
# Microsoft EDA.ipynb
# bom.movie_gross.csv
# name.basics.csv
# rt.movie_info.tsv
# rt.reviews.tsv
# title.akas.csv
# title.basics.csv
# title.crew.csv
# title.principals.csv
# title.ratings.csv
# tmdb.movies.csv
# tn.movie_budgets.csv

# %%
# Importing numpy and Pandas Libraries
import numpy as np # for array computation
import pandas as pd # for data manipulation and analysis
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read/load the data set from the system
#Opening the BOM movie csv file and inspecting it's structure
df = pd.read_csv(
    'bom.movie_gross.csv'
)
df.head() # prints the top rows of a dataFrame; use df.tail() to print the bottom rows
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df.tail()
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %%
df.shape
# Out:
# (3387, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# ### Opening and viewing the title_basics and title_ratings

# %%
#Opening the title_basics csv file and inspecting it's structure
df1 = pd.read_csv(
    'title.basics.csv'
)
df1.head() # prints the top rows of a dataFrame
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#Opening the title_ratings csv file and inspecting it's structure
df2 = pd.read_csv(
    'title.ratings.csv'
)
df2.head() # prints the top rows of a dataFrame
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#Joining the two imdb tables 
imdb = df1.join(df2.set_index('tconst'),
                                   how = 'inner', on = 'tconst', rsuffix = 'r')

# %%
imdb.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
#Drop columns that are not needed.
imdb = imdb.drop(columns = ['original_title', 'runtime_minutes', 'numvotes'])

# %%
#Confirm the dataframe only has required columns
imdb.head()
# Out:
#       tconst                    primary_title  start_year  \
# 0  tt0063540                        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season        2019
# 2  tt0069049       The Other Side of the Wind        2018
# 3  tt0069204                  Sabse Bada Sukh        2018
# 4  tt0100275         The Wandering Soap Opera        2017
#
#                  genres  averagerating
# 0    Action,Crime,Drama            7.0
# 1       Biography,Drama            7.2
# 2                 Drama            6.9
# 3          Comedy,Drama            6.1
# 4  Comedy,Drama,Fantasy            6.5

# %%
#Renaming pimary title to title to facilitate joining with bom.movie_gross.csv
imdb.rename(columns = {'primary_title':'title'}, inplace = True)

# %%
#Confirming the column was renamed
imdb.head()
# Out:
#       tconst                            title  start_year  \
# 0  tt0063540                        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season        2019
# 2  tt0069049       The Other Side of the Wind        2018
# 3  tt0069204                  Sabse Bada Sukh        2018
# 4  tt0100275         The Wandering Soap Opera        2017
#
#                  genres  averagerating
# 0    Action,Crime,Drama            7.0
# 1       Biography,Drama            7.2
# 2                 Drama            6.9
# 3          Comedy,Drama            6.1
# 4  Comedy,Drama,Fantasy            6.5

# %%
imdb
# Out:
#            tconst                            title  start_year  \
# 0       tt0063540                        Sunghursh        2013
# 1       tt0066787  One Day Before the Rainy Season        2019
# 2       tt0069049       The Other Side of the Wind        2018
# 3       tt0069204                  Sabse Bada Sukh        2018
# 4       tt0100275         The Wandering Soap Opera        2017
# ...           ...                              ...         ...
# 146115  tt9913084                 Diabolik sono io        2019
# 146122  tt9914286                Sokagin Çocuklari        2019
# 146125  tt9914642                        Albatross        2017
# 146129  tt9914942       La vida sense la Sara Amat        2019
# 146134  tt9916160                       Drømmeland        2019
#
#                       genres  averagerating
# 0         Action,Crime,Drama            7.0
# 1            Biography,Drama            7.2
# 2                      Drama            6.9
# 3               Comedy,Drama            6.1
# 4       Comedy,Drama,Fantasy            6.5
# ...                      ...            ...
# 146115           Documentary            6.2
# 146122          Drama,Family            8.7
# 146125           Documentary            8.5
# 146129                   NaN            6.6
# 146134           Documentary            6.5
#
# [73856 rows x 5 columns]

# %%
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
#Rename column start_year to year
imdb.rename(columns = {'start_year':'year'}, inplace = True)
imdb
# Out:
#            tconst                            title  year  \
# 0       tt0063540                        Sunghursh  2013
# 1       tt0066787  One Day Before the Rainy Season  2019
# 2       tt0069049       The Other Side of the Wind  2018
# 3       tt0069204                  Sabse Bada Sukh  2018
# 4       tt0100275         The Wandering Soap Opera  2017
# ...           ...                              ...   ...
# 146115  tt9913084                 Diabolik sono io  2019
# 146122  tt9914286                Sokagin Çocuklari  2019
# 146125  tt9914642                        Albatross  2017
# 146129  tt9914942       La vida sense la Sara Amat  2019
# 146134  tt9916160                       Drømmeland  2019
#
#                       genres  averagerating
# 0         Action,Crime,Drama            7.0
# 1            Biography,Drama            7.2
# 2                      Drama            6.9
# 3               Comedy,Drama            6.1
# 4       Comedy,Drama,Fantasy            6.5
# ...                      ...            ...
# 146115           Documentary            6.2
# 146122          Drama,Family            8.7
# 146125           Documentary            8.5
# 146129                   NaN            6.6
# 146134           Documentary            6.5
#
# [73856 rows x 5 columns]

# %%
#Merge both the imdb dataframe and the BOM.csv file 
dataset = pd.merge(imdb, df, on=['title', 'year'], how='inner')
dataset
# Out:
#          tconst                            title  year  \
# 0     tt0315642                            Wazir  2016
# 1     tt0337692                      On the Road  2012
# 2     tt0359950  The Secret Life of Walter Mitty  2013
# 3     tt0365907      A Walk Among the Tombstones  2014
# 4     tt0369610                   Jurassic World  2015
# ...         ...                              ...   ...
# 1842  tt8290698               The Spy Gone North  2018
# 1843  tt8404272           How Long Will I Love U  2018
# 1844  tt8427036                  Helicopter Eela  2018
# 1845  tt9078374                      Last Letter  2018
# 1846  tt9151704        Burn the Stage: The Movie  2018
#
#                        genres  averagerating     studio  domestic_gross  \
# 0          Action,Crime,Drama            7.1    Relbig.       1100000.0
# 1     Adventure,Drama,Romance            6.1        IFC        744000.0
# 2      Adventure,Comedy,Drama            7.3        Fox      58200000.0
# 3          Action,Crime,Drama            6.5       Uni.      26300000.0
# 4     Action,Adventure,Sci-Fi            7.0       Uni.     652300000.0
# ...                       ...            ...        ...             ...
# 1842                    Drama            7.2         CJ        501000.0
# 1843                  Romance            6.5      WGUSA        747000.0
# 1844                    Drama            5.4       Eros         72000.0
# 1845            Drama,Romance            6.4         CL        181000.0
# 1846        Documentary,Music            8.8  Trafalgar       4200000.0
#
#      foreign_gross
# 0              NaN
# 1          8000000
# 2        129900000
# 3         26900000
# 4          1,019.4
# ...            ...
# 1842           NaN
# 1843      82100000
# 1844           NaN
# 1845           NaN
# 1846      16100000
#
# [1847 rows x 8 columns]

# %%
#Clean the data by dropping all rows with null values
dataset.dropna(inplace=True)
dataset
# Out:
#          tconst                            title  year  \
# 1     tt0337692                      On the Road  2012
# 2     tt0359950  The Secret Life of Walter Mitty  2013
# 3     tt0365907      A Walk Among the Tombstones  2014
# 4     tt0369610                   Jurassic World  2015
# 5     tt0376136                    The Rum Diary  2011
# ...         ...                              ...   ...
# 1830  tt7784604                       Hereditary  2018
# 1836  tt7959026                         The Mule  2018
# 1838  tt8097306                    Nobody's Fool  2018
# 1843  tt8404272           How Long Will I Love U  2018
# 1846  tt9151704        Burn the Stage: The Movie  2018
#
#                        genres  averagerating     studio  domestic_gross  \
# 1     Adventure,Drama,Romance            6.1        IFC        744000.0
# 2      Adventure,Comedy,Drama            7.3        Fox      58200000.0
# 3          Action,Crime,Drama            6.5       Uni.      26300000.0
# 4     Action,Adventure,Sci-Fi            7.0       Uni.     652300000.0
# 5                Comedy,Drama            6.2         FD      13100000.0
# ...                       ...            ...        ...             ...
# 1830     Drama,Horror,Mystery            7.3        A24      44100000.0
# 1836     Crime,Drama,Thriller            7.1         WB     103800000.0
# 1838     Comedy,Drama,Romance            4.6       Par.      31700000.0
# 1843                  Romance            6.5      WGUSA        747000.0
# 1846        Documentary,Music            8.8  Trafalgar       4200000.0
#
#      foreign_gross
# 1          8000000
# 2        129900000
# 3         26900000
# 4          1,019.4
# 5         10800000
# ...            ...
# 1830      35300000
# 1836      68700000
# 1838       1800000
# 1843      82100000
# 1846      16100000
#
# [1257 rows x 8 columns]

# %%
#Check the datatype of the foreign_gross column 
dataset['foreign_gross']
# Out:
# 1         8000000
# 2       129900000
# 3        26900000
# 4         1,019.4
# 5        10800000
#           ...
# 1830     35300000
# 1836     68700000
# 1838      1800000
# 1843     82100000
# 1846     16100000
# Name: foreign_gross, Length: 1257, dtype: object

# %%
#change the dtype to float in order to later merge domestic_gross and foreign_gross columns by 
#finding the sum of the two columns and creating a new column total_gross
dataset['foreign_gross'] = pd.to_numeric(dataset['foreign_gross'], errors='coerce')

# Drop rows where 'foreign_gross' is NaN, which means it originally had a string datatype
dataset.dropna(subset=['foreign_gross'], inplace=True)

# %%
dataset['foreign_gross'].dtype
# Out:
# dtype('float64')

# %%
#create the new column total_gross
dataset['total_gross'] = dataset['domestic_gross'] + dataset['foreign_gross']

# Display the DataFrame with the combined column
dataset
# Out:
#          tconst                            title  year  \
# 1     tt0337692                      On the Road  2012
# 2     tt0359950  The Secret Life of Walter Mitty  2013
# 3     tt0365907      A Walk Among the Tombstones  2014
# 5     tt0376136                    The Rum Diary  2011
# 7     tt0383010                The Three Stooges  2012
# ...         ...                              ...   ...
# 1830  tt7784604                       Hereditary  2018
# 1836  tt7959026                         The Mule  2018
# 1838  tt8097306                    Nobody's Fool  2018
# 1843  tt8404272           How Long Will I Love U  2018
# 1846  tt9151704        Burn the Stage: The Movie  2018
#
#                        genres  averagerating     studio  domestic_gross  \
# 1     Adventure,Drama,Romance            6.1        IFC        744000.0
# 2      Adventure,Comedy,Drama            7.3        Fox      58200000.0
# 3          Action,Crime,Drama            6.5       Uni.      26300000.0
# 5                Comedy,Drama            6.2         FD      13100000.0
# 7               Comedy,Family            5.1        Fox      44300000.0
# ...                       ...            ...        ...             ...
# 1830     Drama,Horror,Mystery            7.3        A24      44100000.0
# 1836     Crime,Drama,Thriller            7.1         WB     103800000.0
# 1838     Comedy,Drama,Romance            4.6       Par.      31700000.0
# 1843                  Romance            6.5      WGUSA        747000.0
# 1846        Documentary,Music            8.8  Trafalgar       4200000.0
#
#       foreign_gross  total_gross
# 1         8000000.0    8744000.0
# 2       129900000.0  188100000.0
# 3        26900000.0   53200000.0
# 5        10800000.0   23900000.0
# 7        10500000.0   54800000.0
# ...             ...          ...
# 1830     35300000.0   79400000.0
# 1836     68700000.0  172500000.0
# 1838      1800000.0   33500000.0
# 1843     82100000.0   82847000.0
# 1846     16100000.0   20300000.0
#
# [1253 rows x 9 columns]

# %%
dataset_expanded = dataset.assign(genres=dataset['genres'].str.split(','))

# Explode the 'genre' column to create separate rows for each genre
dataset_expanded = dataset_expanded.explode('genres')
dataset_expanded
# Out:
#          tconst                            title  year       genres  \
# 1     tt0337692                      On the Road  2012    Adventure
# 1     tt0337692                      On the Road  2012        Drama
# 1     tt0337692                      On the Road  2012      Romance
# 2     tt0359950  The Secret Life of Walter Mitty  2013    Adventure
# 2     tt0359950  The Secret Life of Walter Mitty  2013       Comedy
# ...         ...                              ...   ...          ...
# 1838  tt8097306                    Nobody's Fool  2018        Drama
# 1838  tt8097306                    Nobody's Fool  2018      Romance
# 1843  tt8404272           How Long Will I Love U  2018      Romance
# 1846  tt9151704        Burn the Stage: The Movie  2018  Documentary
# 1846  tt9151704        Burn the Stage: The Movie  2018        Music
#
#       averagerating     studio  domestic_gross  foreign_gross  total_gross
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 2               7.3        Fox      58200000.0    129900000.0  188100000.0
# 2               7.3        Fox      58200000.0    129900000.0  188100000.0
# ...             ...        ...             ...            ...          ...
# 1838            4.6       Par.      31700000.0      1800000.0   33500000.0
# 1838            4.6       Par.      31700000.0      1800000.0   33500000.0
# 1843            6.5      WGUSA        747000.0     82100000.0   82847000.0
# 1846            8.8  Trafalgar       4200000.0     16100000.0   20300000.0
# 1846            8.8  Trafalgar       4200000.0     16100000.0   20300000.0
#
# [3227 rows x 9 columns]

# %% [markdown]
# # Start of visualization techniques to compare the number of movies produced per genre

# %%
# vertical barplot
genre_counts = dataset_expanded['genres'].str.split(',', expand=True).stack().value_counts()

plt.figure(figsize=(10, 6))  # Set the size of the plot
genre_counts.plot(kind='bar', color='skyblue', edgecolor='black')

#Add labels and title to the plot
plt.xlabel('Genres')
plt.ylabel('Number of Movies')
plt.title('Count of Movies for Each Genre')

# Display the plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %% [markdown]
# From the vertical bar graph : Drama has the highest number ofmovies between 2010 to 2018, while musicals had the lowest nuber of movies compared to all genres

# %%
#pie chart
plt.figure(figsize=(20, 20))
genre_counts.plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.title('Movies per Genre' , loc='right')
plt.axis('equal')
plt.show()

# %%
#horizontal bar plot
plt.figure(figsize=(10, 6))
genre_counts.sort_values().plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Genres')
plt.title('Count of Movies per Genre')
plt.tight_layout()
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10, 6))
x = range(1, len(genre_counts) + 1)
y = genre_counts.values
plt.scatter(x, y)
plt.xticks(x, genre_counts.index, rotation=45)
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Count of Movies by Genre (Scatter Plot)')
plt.show()

# %%
#line graph
plt.figure(figsize=(10, 6))
x = range(1, len(genre_counts) + 1)
y = genre_counts.values
plt.plot(x, y, marker='o', linestyle='-', linewidth=2)
plt.xticks(x, genre_counts.index, rotation=45)
plt.xlabel('Genres')
plt.ylabel('Count')
plt.title('Count of Movies by Genre (Line Graph)')
plt.show()

# %% [markdown]
# ### Investigating gross earnings per movie genre

# %%
#For ease of visualization, I divided the total gross column by a million to get the gross_in_millions
dataset_expanded['gross_in_millions'] = dataset_expanded['total_gross']/ 1000000
dataset_expanded
# Out:
#          tconst                            title  year       genres  \
# 1     tt0337692                      On the Road  2012    Adventure
# 1     tt0337692                      On the Road  2012        Drama
# 1     tt0337692                      On the Road  2012      Romance
# 2     tt0359950  The Secret Life of Walter Mitty  2013    Adventure
# 2     tt0359950  The Secret Life of Walter Mitty  2013       Comedy
# ...         ...                              ...   ...          ...
# 1838  tt8097306                    Nobody's Fool  2018        Drama
# 1838  tt8097306                    Nobody's Fool  2018      Romance
# 1843  tt8404272           How Long Will I Love U  2018      Romance
# 1846  tt9151704        Burn the Stage: The Movie  2018  Documentary
# 1846  tt9151704        Burn the Stage: The Movie  2018        Music
#
#       averagerating     studio  domestic_gross  foreign_gross  total_gross  \
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 1               6.1        IFC        744000.0      8000000.0    8744000.0
# 2               7.3        Fox      58200000.0    129900000.0  188100000.0
# 2               7.3        Fox      58200000.0    129900000.0  188100000.0
# ...             ...        ...             ...            ...          ...
# 1838            4.6       Par.      31700000.0      1800000.0   33500000.0
# 1838            4.6       Par.      31700000.0      1800000.0   33500000.0
# 1843            6.5      WGUSA        747000.0     82100000.0   82847000.0
# 1846            8.8  Trafalgar       4200000.0     16100000.0   20300000.0
# 1846            8.8  Trafalgar       4200000.0     16100000.0   20300000.0
#
#       gross_in_millions
# 1                 8.744
# 1                 8.744
# 1                 8.744
# 2               188.100
# 2               188.100
# ...                 ...
# 1838             33.500
# 1838             33.500
# 1843             82.847
# 1846             20.300
# 1846             20.300
#
# [3227 rows x 10 columns]

# %% [markdown]
# ### Visualization techniques to compare the gross earnings per movie genre

# %%
# Assuming you have a DataFrame named 'dataset' with columns 'genres' and 'gross_in_millions'

# Group the data by 'genres' and sum the 'gross_in_millions' for each genre
genre_gross_sum = dataset_expanded.groupby('genres')['gross_in_millions'].sum()

# horizontal bar graph to show total gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_sum.sort_values().plot(kind='barh')
plt.xlabel('Total Gross Earnings (Millions)')
plt.ylabel('Genres')
plt.title('Total Gross Earnings per Movie Genre (Horizontal Bar Graph)')
plt.show()

# %%
 #vertical bar graph to show total gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_sum.sort_values().plot(kind='bar')
plt.xlabel('Genres')
plt.ylabel('Total Gross Earnings (Millions)')
plt.title('Total Gross Earnings per Movie Genre (Vertical Bar Graph)')
plt.show()

# %% [markdown]
# Adventure and Action had the highesttotal gross earnings per genre

# %%
#a scatter plot to show total gross earnings per movie genre
plt.figure(figsize=(10, 6))
plt.scatter(genre_gross_sum.index, genre_gross_sum.values)
plt.xlabel('Genres')
plt.ylabel('Total Gross Earnings (Millions)')
plt.title('Total Gross Earnings per Movie Genre (Scatter Plot)')
plt.xticks(rotation=45)
plt.show()

# %%
#a pie chart to show total gross earnings distribution per movie genre
plt.figure(figsize=(24, 24))
genre_gross_sum.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Total Gross Earnings Distribution per Movie Genre (Pie Chart)',loc='right')
plt.axis('equal')
plt.show()

# %%
# A line graph to show total gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_sum.sort_values().plot(marker='o', linestyle='-', linewidth=2)
plt.xlabel('Genres')
plt.ylabel('Total Gross Earnings (Millions)')
plt.title('Total Gross Earnings per Movie Genre (Line Graph)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Getting the average gross earnings per movie genre

# %%
genre_gross_avg = dataset_expanded.groupby('genres')['gross_in_millions'].mean()

# a horizontal bar graph to show average gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_avg.sort_values().plot(kind='barh')
plt.xlabel('Average Gross Earnings (Millions)')
plt.ylabel('Genres')
plt.title('Average Gross Earnings per Movie Genre (Horizontal Bar Graph)')
plt.show()

# %%
#vertical bar graph to show average gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_avg.sort_values().plot(kind='bar')
plt.xlabel('Genres')
plt.ylabel('Average Gross Earnings (Millions)')
plt.title('Average Gross Earnings per Movie Genre (Vertical Bar Graph)')
plt.show()

# %% [markdown]
# Adventure, Sci-Fi and Animation had the highest averages in terms of gross earnings while Documentary had the lowest

# %%
#a scatter plot to show average gross earnings per movie genre
plt.figure(figsize=(10, 6))
plt.scatter(genre_gross_avg.index, genre_gross_avg.values)
plt.xlabel('Genres')
plt.ylabel('Average Gross Earnings (Millions)')
plt.title('Average Gross Earnings per Movie Genre (Scatter Plot)')
plt.xticks(rotation=45)
plt.show()

# %%
#a pie chart to show average gross earnings distribution per movie genre
plt.figure(figsize=(24, 24))
genre_gross_avg.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Average Gross Earnings Distribution per Movie Genre (Pie Chart)' , loc = 'right')
plt.axis('equal')
plt.show()

# %%
#a line graph to show average gross earnings per movie genre
plt.figure(figsize=(10, 6))
genre_gross_avg.sort_values().plot(marker='o', linestyle='-', linewidth=2)
plt.xlabel('Genres')
plt.ylabel('Average Gross Earnings (Millions)')
plt.title('Average Gross Earnings per Movie Genre (Line Graph)')
plt.xticks(rotation=45)
plt.show()

# %%
lowest_year = dataset_expanded['year'].min()
highest_year = dataset_expanded['year'].max()
print("Lowest year:", lowest_year)
print("Highest year:", highest_year)
# Out:
# Lowest year: 2010
# Highest year: 2018

# %% [markdown]
# ## Conclusion

# %% [markdown]
#  The study was conducted for movies between 2010 and 2018 and involved total gross earnings, genres and the number of movies       produced per genre.
#
#  The following are the recommendations:
#
#  1.The studio should produce Sci-fi,Animation, Adventure, Fantasy or Action since they average over 250 million dollars a year.
#
#  2.The studio should also aim to produce adventure and action since they have been the most consistent in terms of total gross      earnings.
#
#  3.The studio shoukd also venture into sci-fi and animation since they have a lower number of movies produced and result in a      very high gross averages hence can be unexplored potential.
